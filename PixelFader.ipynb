# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline  

# reads image 'opencv-logo.png' as grayscale
img = cv2.imread('me.jpg') 
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGBA))

## create alpha channel
b_channel, g_channel, r_channel = cv2.split(img)
alpha_channel = np.ones(b_channel.shape, dtype=b_channel.dtype) * 255 #creating a dummy alpha channel image.
img = cv2.merge((b_channel, g_channel, r_channel, alpha_channel))

# %%
print(img[0,0])
# Out:
# [196 138 109 255]

# %%
## generate blank image

import numpy as np
import cv2
height = img.shape[0]
width = img.shape[1]
channels = 3

# %%
import random

# fine tunable param
f = 5
thresh = 0.05
start = int(dim_w * thresh)
img = cv2.resize(img, (f*(width//f), f*(height//f)))
dim_h = height//f
dim_w = width //f
mask = [[1 for i in range(dim_w)] for j in range(dim_h)] 
for i in range(dim_h):
    for j in range(start, dim_w):
        mask[i][j] = random.choices([1, 0], weights=[300 - 300 * (j/dim_w), 20], k = 1)[0]
#print(mask)

# %%
print(dim_h)
print(dim_w)
# Out:
# 153
# 204

# %%
import math
s = 0

for i in range((height//f)*f):
    for j in range((width//f) * f):
        #s = max(i//f, s)
        #print(Math.floor(i//f))
        #print(j//f)
        if (mask[i//f][j//f] != 1):
            img[i][j] = (255,255,255,0)
print(s)
#uint_img = np.array(mask*255).astype('uint8')
#grayImage = cv2.cvtColor(uint_img, cv2.COLOR_GRAY2BGR)
#resized = cv2.resize(grayImage, (width, height), interpolation = cv2.INTER_LINEAR)
#cv2.imwrite('mask.jpg', resized)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# 0

# %%
cv2.imwrite('mask.png', img)
# Out:
# True
